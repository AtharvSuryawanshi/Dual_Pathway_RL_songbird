# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.load("all_rewards.npy")
a.shape
# Out:
# (10, 61, 1000)

# %%
b = a.reshape(10, 61000)
plt.figure(figsize=(15, 3))
plt.plot(b[:, :].T, alpha=0.3)
plt.xlabel("Episode")           
plt.ylabel("Reward")
plt.title("Rewards over 50 seeds")  
plt.show()
